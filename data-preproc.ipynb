# %%
import pandas as pd
import regex as re

# %%
df = pd.read_csv('./datasets/Reviews.csv', index_col=0)
df.head()
# Out:
#      ProductId          UserId                      ProfileName  \
# Id
# 1   B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 2   B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 3   B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 4   B000UA0QIQ  A395BORC6FGVXV                             Karl
# 5   B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#     HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# Id
# 1                      1                       1      5  1303862400
# 2                      0                       0      1  1346976000
# 3                      1                       1      4  1219017600
# 4                      3                       3      2  1307923200
# 5                      0                       0      5  1350777600
#
#                   Summary                                               Text
# Id
# 1   Good Quality Dog Food  I have bought several of the Vitality canned d...
# 2       Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 3   "Delight" says it all  This is a confection that has been around a fe...
# 4          Cough Medicine  If you are looking for the secret ingredient i...
# 5             Great taffy  Great taffy at a great price.  There was a wid...

# %%
print("original shape: ", df.shape)
df = df.drop_duplicates()
print("after drop duplicates shape: ", df.shape)
df = df.dropna()
print("after drop null shape: ", df.shape)
# Out:
# original shape:  (568454, 9)
# after drop duplicates shape:  (568173, 9)
# after drop null shape:  (568130, 9)

# %%
def cleaning_func(text):
    text = text if type(text) == str else str(text)
    # convert to lowercase
    text = text.lower()
    # remove non alphanumeric characters
    text = re.sub(r'[^A-Za-z0-9]+', ' ', text)
    # remove multiple spaces
    text = re.sub(r'\s+', ' ', text)
    # remove leading and trailing spaces
    text = text.strip()
    
    return text

# %%
columns_to_clean = ["Text", "Summary", "ProfileName"]

# %%
for col in df.columns:
    if col in columns_to_clean:
        df[col] = df[col].apply(cleaning_func)
df.head()
# Out:
#      ProductId          UserId                    ProfileName  \
# Id
# 1   B001E4KFG0  A3SGXH7AUHU8GW                     delmartian
# 2   B00813GRG4  A1D87F6ZCVE5NK                         dll pa
# 3   B000LQOCH0   ABXLMWJIXXAIN  natalia corres natalia corres
# 4   B000UA0QIQ  A395BORC6FGVXV                           karl
# 5   B006K2ZZ7K  A1UQRSCLF8GW1T      michael d bigham m wassir
#
#     HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# Id
# 1                      1                       1      5  1303862400
# 2                      0                       0      1  1346976000
# 3                      1                       1      4  1219017600
# 4                      3                       3      2  1307923200
# 5                      0                       0      5  1350777600
#
#                   Summary                                               Text
# Id
# 1   good quality dog food  i have bought several of the vitality canned d...
# 2       not as advertised  product arrived labeled as jumbo salted peanut...
# 3     delight says it all  this is a confection that has been around a fe...
# 4          cough medicine  if you are looking for the secret ingredient i...
# 5             great taffy  great taffy at a great price there was a wide ...

# %%
df = df.reindex(range(len(df.index))[1:])

# %%
print("original shape: ", df.shape)
df = df.dropna()
print("after drop null shape: ", df.shape)
df = df.drop_duplicates()
print("after drop duplicates shape: ", df.shape)
# Out:
# original shape:  (568129, 9)
# after drop null shape:  (567805, 9)
# after drop duplicates shape:  (567791, 9)

# %%
df["HelpfulnessNumerator"] = df["HelpfulnessNumerator"].apply(lambda f: format(f, '.0f'))
df["HelpfulnessDenominator"] = df["HelpfulnessDenominator"].apply(lambda f: format(f, '.0f'))
df["Score"] = df["Score"].apply(lambda f: format(f, '.0f'))
df["Time"] = df["Time"].apply(lambda f: format(f, '.0f'))

df["HelpfulnessNumerator"] = df["HelpfulnessNumerator"].fillna(0)
df["HelpfulnessDenominator"] = df["HelpfulnessDenominator"].fillna(0)

# %%
df.to_csv('./datasets/Reviews_cleaned.csv')
